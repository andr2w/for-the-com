# %% [markdown]
# # By Yifeng Luo

# %%
import time 
import torch
import numpy as np
from model import Bert
import utils
import train 
import warnings
warnings.filterwarnings('ignore')

# %%
# Co
dataset = './tdata/'
config = Bert.Config(dataset)
config.train_path = './tdata/co_training.csv'
config.test_path = './tdata/co_test.csv'
config.dev_path = './tdata/co_dev.csv'
config.model_name = 'BERT_co'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = Bert.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:00
# Epoch [1/20
# Iter:     0, Train Loss: 0.85, Train Acc:  0.25, Val Loss:  1.1, Val Acc:28.46%, Time:0:00:04 *
# Iter:   100, Train Loss:  0.9, Train Acc:  0.75, Val Loss:0.079, Val Acc:98.37%, Time:0:00:59 *
# Epoch [2/20
# Iter:   200, Train Loss:0.049, Train Acc:   1.0, Val Loss: 0.14, Val Acc:97.56%, Time:0:01:53
# Epoch [3/20
# Iter:   300, Train Loss:0.017, Train Acc:   1.0, Val Loss:0.063, Val Acc:97.56%, Time:0:02:48 *
# Epoch [4/20
# Iter:   400, Train Loss:0.0058, Train Acc:   1.0, Val Loss: 0.08, Val Acc:97.56%, Time:0:03:43
# Epoch [5/20
# Iter:   500, Train Loss: 0.58, Train Acc:  0.88, Val Loss: 0.17, Val Acc:95.12%, Time:0:04:37
# Iter:   600, Train Loss:0.0088, Train Acc:   1.0, Val Loss:0.055, Val Acc:96.75%, Time:0:05:32 *
# Epoch [6/20
# Iter:   700, Train Loss:0.045, Train Acc:   1.0, Val Loss: 0.17, Val Acc:94.31%, Time:0:06:29
# Epoch [7/20
# Iter:   800, Train Loss:0.013, Train Acc:   1.0, Val Loss:0.062, Val Acc:98.37%, Time:0:07:23
# Epoch [8/20
# Iter:   900, Train Loss:0.0061, Train Acc:   1.0, Val Loss:0.067, Val Acc:98.37%, Time:0:08:18
# Epoch [9/20
# Iter:  1000, Train Loss:0.0097, Train Acc:   1.0, Val Loss:0.068, Val Acc:98.37%, Time:0:09:12
# Iter:  1100, Train Loss:0.015, Train Acc:   1.0, Val Loss:0.072, Val Acc:98.37%, Time:0:10:06
# Epoch [10/20
# Iter:  1200, Train Loss:0.016, Train Acc:   1.0, Val Loss: 0.11, Val Acc:96.75%, Time:0:11:01
# Epoch [11/20
# Iter:  1300, Train Loss: 0.01, Train Acc:   1.0, Val Loss:0.069, Val Acc:98.37%, Time:0:11:55
# Epoch [12/20
# Iter:  1400, Train Loss:0.005, Train Acc:   1.0, Val Loss:0.076, Val Acc:97.56%, Time:0:12:50
# Epoch [13/20
# Iter:  1500, Train Loss:0.00057, Train Acc:   1.0, Val Loss:0.069, Val Acc:99.19%, Time:0:13:44
# Epoch [14/20
# Iter:  1600, Train Loss:0.0098, Train Acc:   1.0, Val Loss:0.075, Val Acc:98.37%, Time:0:14:39
# The model has not improve for a quit long time, stop training
# Test Loss: 0.31, Test Acc:94.31%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.9576    0.9826    0.9700       115
#            1     0.6000    0.3750    0.4615         8
#
#     accuracy                         0.9431       123
#    macro avg     0.7788    0.6788    0.7157       123
# weighted avg     0.9344    0.9431    0.9369       123
#
# Confusion Maxtrix
# [[113   2]
#  [  5   3]]
# Using Time 0:00:02

# %%
# en
dataset = './tdata/'
config = Bert.Config(dataset)
config.train_path = './tdata/en_training.csv'
config.test_path = './tdata/en_test.csv'
config.dev_path = './tdata/en_dev.csv'
config.model_name = 'BERT_en'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = Bert.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:01
# Epoch [1/20
# Iter:     0, Train Loss: 0.58, Train Acc:  0.62, Val Loss: 0.74, Val Acc:60.48%, Time:0:00:06 *
# Iter:   100, Train Loss: 0.64, Train Acc:  0.62, Val Loss: 0.42, Val Acc:81.90%, Time:0:01:03 *
# Iter:   200, Train Loss: 0.47, Train Acc:  0.75, Val Loss:  0.4, Val Acc:84.29%, Time:0:02:01 *
# Epoch [2/20
# Iter:   300, Train Loss: 0.71, Train Acc:  0.75, Val Loss: 0.47, Val Acc:84.29%, Time:0:02:57
# Iter:   400, Train Loss: 0.45, Train Acc:  0.75, Val Loss:  0.4, Val Acc:85.24%, Time:0:03:56 *
# Epoch [3/20
# Iter:   500, Train Loss: 0.35, Train Acc:  0.88, Val Loss: 0.54, Val Acc:85.71%, Time:0:04:52
# Iter:   600, Train Loss: 0.15, Train Acc:   1.0, Val Loss: 0.38, Val Acc:85.71%, Time:0:05:49 *
# Epoch [4/20
# Iter:   700, Train Loss: 0.28, Train Acc:  0.75, Val Loss: 0.46, Val Acc:84.29%, Time:0:06:45
# Iter:   800, Train Loss: 0.25, Train Acc:  0.88, Val Loss: 0.42, Val Acc:85.24%, Time:0:07:41
# Epoch [5/20
# Iter:   900, Train Loss: 0.19, Train Acc:   1.0, Val Loss: 0.47, Val Acc:86.67%, Time:0:08:38
# Iter:  1000, Train Loss:0.033, Train Acc:   1.0, Val Loss: 0.49, Val Acc:85.71%, Time:0:09:34
# Epoch [6/20
# Iter:  1100, Train Loss:0.049, Train Acc:   1.0, Val Loss:  0.5, Val Acc:85.71%, Time:0:10:30
# Iter:  1200, Train Loss: 0.04, Train Acc:   1.0, Val Loss: 0.49, Val Acc:86.67%, Time:0:11:26
# Epoch [7/20
# Iter:  1300, Train Loss: 0.24, Train Acc:  0.88, Val Loss: 0.51, Val Acc:84.29%, Time:0:12:22
# Iter:  1400, Train Loss:  0.1, Train Acc:   1.0, Val Loss: 0.51, Val Acc:85.24%, Time:0:13:19
# Epoch [8/20
# Iter:  1500, Train Loss: 0.12, Train Acc:  0.88, Val Loss: 0.53, Val Acc:85.71%, Time:0:14:15
# Iter:  1600, Train Loss: 0.29, Train Acc:  0.88, Val Loss: 0.57, Val Acc:85.24%, Time:0:15:11
# The model has not improve for a quit long time, stop training
# Test Loss: 0.32, Test Acc:88.57%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.8250    0.9706    0.8919       102
#            1     0.9667    0.8056    0.8788       108
#
#     accuracy                         0.8857       210
#    macro avg     0.8958    0.8881    0.8853       210
# weighted avg     0.8979    0.8857    0.8852       210
#
# Confusion Maxtrix
# [[99  3]
#  [21 87]]
# Using Time 0:00:04

# %%
# so
dataset = './tdata/'
config = Bert.Config(dataset)
config.train_path = './tdata/so_training.csv'
config.test_path = './tdata/so_test.csv'
config.dev_path = './tdata/so_dev.csv'
config.model_name = 'BERT_so'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = Bert.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:02
# Epoch [1/20
# Iter:     0, Train Loss: 0.75, Train Acc:  0.38, Val Loss: 0.65, Val Acc:71.98%, Time:0:00:06 *
# Iter:   100, Train Loss: 0.13, Train Acc:   1.0, Val Loss: 0.36, Val Acc:89.86%, Time:0:01:03 *
# Iter:   200, Train Loss:0.065, Train Acc:   1.0, Val Loss: 0.26, Val Acc:90.34%, Time:0:02:00 *
# Epoch [2/20
# Iter:   300, Train Loss:  0.4, Train Acc:  0.75, Val Loss: 0.27, Val Acc:91.79%, Time:0:02:56
# Iter:   400, Train Loss: 0.35, Train Acc:  0.88, Val Loss: 0.36, Val Acc:90.34%, Time:0:03:52
# Epoch [3/20
# Iter:   500, Train Loss: 0.35, Train Acc:  0.88, Val Loss:  0.3, Val Acc:90.82%, Time:0:04:48
# Iter:   600, Train Loss:  1.3, Train Acc:  0.75, Val Loss: 0.39, Val Acc:90.82%, Time:0:05:44
# Epoch [4/20
# Iter:   700, Train Loss:0.034, Train Acc:   1.0, Val Loss: 0.35, Val Acc:89.86%, Time:0:06:40
# Iter:   800, Train Loss:0.012, Train Acc:   1.0, Val Loss:  0.4, Val Acc:90.82%, Time:0:07:36
# Epoch [5/20
# Iter:   900, Train Loss: 0.47, Train Acc:  0.88, Val Loss: 0.37, Val Acc:92.27%, Time:0:08:32
# Iter:  1000, Train Loss:0.036, Train Acc:   1.0, Val Loss: 0.37, Val Acc:91.79%, Time:0:09:28
# Epoch [6/20
# Iter:  1100, Train Loss:0.0033, Train Acc:   1.0, Val Loss: 0.44, Val Acc:90.34%, Time:0:10:24
# Iter:  1200, Train Loss:0.029, Train Acc:   1.0, Val Loss: 0.45, Val Acc:90.34%, Time:0:11:20
# The model has not improve for a quit long time, stop training
# Test Loss: 0.24, Test Acc:92.75%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.9160    0.9561    0.9356       114
#            1     0.9432    0.8925    0.9171        93
#
#     accuracy                         0.9275       207
#    macro avg     0.9296    0.9243    0.9264       207
# weighted avg     0.9282    0.9275    0.9273       207
#
# Confusion Maxtrix
# [[109   5]
#  [ 10  83]]
# Using Time 0:00:04
