# %% [markdown]
# # By Yifeng Luo

# %%
import time 
import torch
import numpy as np
from model import BERTRNN
import utils
import train 
import warnings
warnings.filterwarnings('ignore')

# %%
dataset = './tdata/'
config = BERTRNN.Config(dataset)
config.train_path = './tdata/co_training.csv'
config.test_path = './tdata/co_test.csv'
config.dev_path = './tdata/co_dev.csv'
config.model_name = 'BERTRNN_co'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = BERTRNN.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:00
# Epoch [1/20
# Iter:     0, Train Loss: 0.71, Train Acc:  0.25, Val Loss: 0.71, Val Acc: 8.13%, Time:0:00:04 *
# Iter:   100, Train Loss: 0.76, Train Acc:  0.75, Val Loss:0.088, Val Acc:98.37%, Time:0:01:07 *
# Epoch [2/20
# Iter:   200, Train Loss:0.081, Train Acc:   1.0, Val Loss:  0.1, Val Acc:98.37%, Time:0:02:08
# Epoch [3/20
# Iter:   300, Train Loss:0.036, Train Acc:   1.0, Val Loss:0.085, Val Acc:98.37%, Time:0:03:11 *
# Epoch [4/20
# Iter:   400, Train Loss:0.029, Train Acc:   1.0, Val Loss:0.087, Val Acc:97.56%, Time:0:04:13
# Epoch [5/20
# Iter:   500, Train Loss: 0.98, Train Acc:  0.75, Val Loss: 0.15, Val Acc:92.68%, Time:0:05:15
# Iter:   600, Train Loss:0.023, Train Acc:   1.0, Val Loss:0.087, Val Acc:97.56%, Time:0:06:17
# Epoch [6/20
# Iter:   700, Train Loss:0.028, Train Acc:   1.0, Val Loss: 0.13, Val Acc:95.93%, Time:0:07:19
# Epoch [7/20
# Iter:   800, Train Loss: 0.02, Train Acc:   1.0, Val Loss: 0.14, Val Acc:95.93%, Time:0:08:21
# Epoch [8/20
# Iter:   900, Train Loss:0.018, Train Acc:   1.0, Val Loss:  0.1, Val Acc:96.75%, Time:0:09:23
# Epoch [9/20
# Iter:  1000, Train Loss:0.035, Train Acc:   1.0, Val Loss: 0.11, Val Acc:96.75%, Time:0:10:25
# Iter:  1100, Train Loss:0.025, Train Acc:   1.0, Val Loss: 0.11, Val Acc:96.75%, Time:0:11:28
# Epoch [10/20
# Iter:  1200, Train Loss:0.023, Train Acc:   1.0, Val Loss: 0.11, Val Acc:97.56%, Time:0:12:30
# Epoch [11/20
# Iter:  1300, Train Loss:0.034, Train Acc:   1.0, Val Loss:  0.1, Val Acc:97.56%, Time:0:13:32
# The model has not improve for a quit long time, stop training
# Test Loss: 0.24, Test Acc:93.50%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.9350    1.0000    0.9664       115
#            1     0.0000    0.0000    0.0000         8
#
#     accuracy                         0.9350       123
#    macro avg     0.4675    0.5000    0.4832       123
# weighted avg     0.8741    0.9350    0.9035       123
#
# Confusion Maxtrix
# [[115   0]
#  [  8   0]]
# Using Time 0:00:03

# %%
# en
dataset = './tdata/'
config = BERTRNN.Config(dataset)
config.train_path = './tdata/en_training.csv'
config.test_path = './tdata/en_test.csv'
config.dev_path = './tdata/en_dev.csv'
config.model_name = 'BERTRNN_en'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = BERTRNN.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:01
# Epoch [1/20
# Iter:     0, Train Loss:  0.7, Train Acc:  0.38, Val Loss: 0.69, Val Acc:50.00%, Time:0:00:06 *
# Iter:   100, Train Loss: 0.65, Train Acc:  0.62, Val Loss: 0.43, Val Acc:84.29%, Time:0:01:10 *
# Iter:   200, Train Loss: 0.54, Train Acc:  0.75, Val Loss: 0.44, Val Acc:80.95%, Time:0:02:14
# Epoch [2/20
# Iter:   300, Train Loss: 0.52, Train Acc:  0.75, Val Loss: 0.52, Val Acc:80.95%, Time:0:03:18
# Iter:   400, Train Loss: 0.49, Train Acc:  0.75, Val Loss: 0.44, Val Acc:82.38%, Time:0:04:22
# Epoch [3/20
# Iter:   500, Train Loss: 0.32, Train Acc:  0.88, Val Loss: 0.41, Val Acc:85.71%, Time:0:05:27 *
# Iter:   600, Train Loss: 0.12, Train Acc:   1.0, Val Loss: 0.45, Val Acc:82.86%, Time:0:06:30
# Epoch [4/20
# Iter:   700, Train Loss: 0.24, Train Acc:  0.88, Val Loss:  0.4, Val Acc:86.19%, Time:0:07:35 *
# Iter:   800, Train Loss: 0.26, Train Acc:  0.88, Val Loss: 0.42, Val Acc:84.29%, Time:0:08:39
# Epoch [5/20
# Iter:   900, Train Loss: 0.27, Train Acc:  0.88, Val Loss:  0.4, Val Acc:85.71%, Time:0:09:43
# Iter:  1000, Train Loss:0.079, Train Acc:   1.0, Val Loss: 0.41, Val Acc:84.76%, Time:0:10:46
# Epoch [6/20
# Iter:  1100, Train Loss:0.056, Train Acc:   1.0, Val Loss: 0.39, Val Acc:87.14%, Time:0:11:51 *
# Iter:  1200, Train Loss: 0.21, Train Acc:  0.88, Val Loss: 0.39, Val Acc:82.38%, Time:0:12:56 *
# Epoch [7/20
# Iter:  1300, Train Loss: 0.29, Train Acc:  0.88, Val Loss: 0.44, Val Acc:84.76%, Time:0:13:59
# Iter:  1400, Train Loss: 0.27, Train Acc:  0.88, Val Loss: 0.43, Val Acc:84.29%, Time:0:15:03
# Epoch [8/20
# Iter:  1500, Train Loss: 0.17, Train Acc:  0.88, Val Loss: 0.45, Val Acc:85.71%, Time:0:16:07
# Iter:  1600, Train Loss: 0.23, Train Acc:  0.88, Val Loss: 0.45, Val Acc:85.71%, Time:0:17:11
# Epoch [9/20
# Iter:  1700, Train Loss: 0.32, Train Acc:  0.88, Val Loss: 0.44, Val Acc:84.76%, Time:0:18:14
# Iter:  1800, Train Loss:0.054, Train Acc:   1.0, Val Loss: 0.45, Val Acc:83.33%, Time:0:19:18
# Epoch [10/20
# Iter:  1900, Train Loss: 0.29, Train Acc:  0.88, Val Loss: 0.46, Val Acc:84.76%, Time:0:20:22
# Iter:  2000, Train Loss: 0.22, Train Acc:  0.88, Val Loss: 0.41, Val Acc:85.24%, Time:0:21:27
# Epoch [11/20
# Iter:  2100, Train Loss: 0.42, Train Acc:  0.75, Val Loss: 0.49, Val Acc:85.24%, Time:0:22:30
# Iter:  2200, Train Loss: 0.28, Train Acc:  0.88, Val Loss: 0.44, Val Acc:86.19%, Time:0:23:34
# The model has not improve for a quit long time, stop training
# Test Loss: 0.31, Test Acc:87.14%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.8261    0.9314    0.8756       102
#            1     0.9263    0.8148    0.8670       108
#
#     accuracy                         0.8714       210
#    macro avg     0.8762    0.8731    0.8713       210
# weighted avg     0.8776    0.8714    0.8712       210
#
# Confusion Maxtrix
# [[95  7]
#  [20 88]]
# Using Time 0:00:05

# %%
dataset = './tdata/'
config = BERTRNN.Config(dataset)
config.train_path = './tdata/so_training.csv'
config.test_path = './tdata/so_test.csv'
config.dev_path = './tdata/so_dev.csv'
config.model_name = 'BERTRNN_so'

# make sure the result is the same 
np.random.seed(1000)
torch.manual_seed(1000)
torch.cuda.manual_seed_all(4)
torch.backends.cudnn.deterministic = True

start_time = time.time()
print('We are Loading the dataset now....')
train_data, dev_data, test_data = utils.bulid_dataset(config)
print('Successfully split the data into Train, dev, test')
print('Now into the next, Build iterator')
train_iter = utils.bulid_iterator(train_data, config)
dev_iter = utils.bulid_iterator(dev_data, config)
test_iter = utils.bulid_iterator(test_data, config)

time_dif = utils.get_time_dif(start_time)
print('Loading data cost: ', time_dif)

# start training 
model = BERTRNN.Model(config).to(config.device)
train.train(config, model, train_iter, dev_iter, test_iter)
# Out:
# We are Loading the dataset now....
# Successfully split the data into Train, dev, test
# Now into the next, Build iterator
# Loading data cost:  0:00:02
# Epoch [1/20
# Iter:     0, Train Loss: 0.71, Train Acc:  0.38, Val Loss:  0.7, Val Acc:35.75%, Time:0:00:06 *
# Iter:   100, Train Loss: 0.27, Train Acc:  0.88, Val Loss: 0.33, Val Acc:90.34%, Time:0:01:10 *
# Iter:   200, Train Loss: 0.13, Train Acc:   1.0, Val Loss:  0.3, Val Acc:90.82%, Time:0:02:15 *
# Epoch [2/20
# Iter:   300, Train Loss: 0.32, Train Acc:  0.88, Val Loss: 0.32, Val Acc:89.86%, Time:0:03:18
# Iter:   400, Train Loss: 0.39, Train Acc:  0.88, Val Loss: 0.28, Val Acc:90.82%, Time:0:04:23 *
# Epoch [3/20
# Iter:   500, Train Loss: 0.32, Train Acc:  0.88, Val Loss: 0.26, Val Acc:91.79%, Time:0:05:27 *
# Iter:   600, Train Loss: 0.57, Train Acc:  0.88, Val Loss:  0.3, Val Acc:91.79%, Time:0:06:31
# Epoch [4/20
# Iter:   700, Train Loss:0.039, Train Acc:   1.0, Val Loss: 0.31, Val Acc:91.30%, Time:0:07:35
# Iter:   800, Train Loss:0.027, Train Acc:   1.0, Val Loss: 0.35, Val Acc:91.79%, Time:0:08:39
# Epoch [5/20
# Iter:   900, Train Loss: 0.47, Train Acc:  0.75, Val Loss: 0.28, Val Acc:91.30%, Time:0:09:42
# Iter:  1000, Train Loss:0.092, Train Acc:   1.0, Val Loss: 0.36, Val Acc:91.30%, Time:0:10:46
# Epoch [6/20
# Iter:  1100, Train Loss:0.021, Train Acc:   1.0, Val Loss:  0.3, Val Acc:91.79%, Time:0:11:50
# Iter:  1200, Train Loss:0.018, Train Acc:   1.0, Val Loss: 0.35, Val Acc:91.79%, Time:0:12:54
# Epoch [7/20
# Iter:  1300, Train Loss: 0.35, Train Acc:  0.88, Val Loss: 0.32, Val Acc:91.30%, Time:0:13:57
# Iter:  1400, Train Loss: 0.35, Train Acc:  0.88, Val Loss: 0.35, Val Acc:91.79%, Time:0:15:01
# Epoch [8/20
# Iter:  1500, Train Loss: 0.38, Train Acc:  0.88, Val Loss: 0.34, Val Acc:91.79%, Time:0:16:05
# The model has not improve for a quit long time, stop training
# Test Loss: 0.25, Test Acc:91.30%
# Precision, Recall and F1-Score
#               precision    recall  f1-score   support
#
#            0     0.9138    0.9298    0.9217       114
#            1     0.9121    0.8925    0.9022        93
#
#     accuracy                         0.9130       207
#    macro avg     0.9129    0.9111    0.9120       207
# weighted avg     0.9130    0.9130    0.9129       207
#
# Confusion Maxtrix
# [[106   8]
#  [ 10  83]]
# Using Time 0:00:04
